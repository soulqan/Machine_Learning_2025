# %% [markdown]
# <a href="https://colab.research.google.com/github/soulqan/Machine_Learning_2025/blob/main/TG1_2341720191_Soultan_Mohammad_Agnar_Bisyarah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Jobsheet1

# %%
# !pip install pyprep scipy wandb
# pyecg
# Out:
# ...
#   Using cached pyprep-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mne-1.10.1-py3-none-any.whl.metadata (20 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 83.0 MB/s eta 0:00:00
# ...

# %%
import pyprep
import scipy
import wandb
#import pyecg

# %% [markdown]
# jelaskan kegunakan masing-masing library tersebut.
#
#
# 1.   PyPREP adalah Library Python untuk Preprocessing sinyal EEG.
# Digunakan untuk menghilangkan noise dan artefak pada data EEG.
# 2.   SciPy adalah salah satu library ilmiah dan numerik paling populer di Python.
# Digunakan untuk operasi matematika tingkat lanjut
# 3. wandb adalah Platform untuk tracking eksperimen machine learning.
# Digunakan untuk Mencatat hasil training (loss, akurasi, grafik),menyimpan model, dataset, dan konfigurasi hyperparameter.
# 4. Pyecg adalah paket Python open source yang mendukung baca/tulis format dataset ECG yang umum.
# Digunakan untuk membaca, memproses, dan menganalisis sinyal ECG.

# %% [markdown]
# Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
# 1. Penyebaran disinformasi dan deepfake
#
# AI dapat menciptakan konten palsu yang sangat meyakinkan, seperti video atau teks palsu, yang dapat merusak proses demokrasi dan memicu penyebaran informasi sesat.
# https://en.antaranews.com/news/378189/government-prepares-ai-ethics-guidelines-to-tackle-disinformation
#
# 2. Kurangnya kerangka hukum untuk penggunaan AI di pendidikan
#
# Di Indonesia, belum ada regulasi nasional yang kuat terkait penggunaan AI dalam konteks ujian atau pendidikan—misalnya, untuk mencegah penggunaan AI dalam pengisian soal.
# https://engagemedia.org/2025/2022-2024-media-monitoring-impact-artificial-intelligence-indonesia
#
# 3. Ketidakterbukaan dan potensi diskriminasi algoritmik
#
# Secara global, sistem AI bisa mengandung bias bila data latih tidak representatif, yang berisiko melanggar prinsip keadilan dan nondiskriminasi.
# https://www.bricscompetition.org/news/indonesia-publishes-ai-roadmap-ethics-framework
#
# Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
# Dampak Energi & Lingkungan dari Pemanfaatan AI
#
# 1. Konsumsi listrik yang sangat besar
#
# Menurut MIT News, pelatihan model AI generatif skala besar seperti GPT membutuhkan daya komputasi yang sangat tinggi sehingga mengonsumsi energi listrik dalam jumlah besar. Hal ini meningkatkan emisi gas rumah kaca jika https://news.mit.edu/2025/explained-generative-ai-environmental-impact-0117
#
# Cara Mengatasi:
#
# Transisi ke energi terbarukan → pusat data harus menggunakan energi matahari, angin, atau nuklir
#
# Optimisasi model → gunakan teknik knowledge distillation dan model pruning agar AI tidak perlu dilatih dengan dataset super besar.
#
# 2. Konsumsi air untuk pendinginan pusat data
#
# Associated Press (AP) melaporkan pusat data yang digunakan untuk menjalankan AI bisa mengonsumsi hingga 5 juta galon air per hari untuk sistem pendinginan. Hal ini menimbulkan dilema etis, terutama di wilayah yang rawan kekeringan.
# https://apnews.com/article/ai-data-center-climate-impact-environment-c6218681ffdbad5bf427b47347fddcb9
#
# Cara Mengatasi:
#
# Teknologi pendinginan alternatif → gunakan pendinginan dengan udara luar, pendinginan cair tertutup, atau pendinginan bawah tanah untuk mengurangi kebutuhan air.
#
# Daur ulang air → gunakan kembali air limbah industri untuk pendinginan, alih-alih menggunakan air minum.

# %% [markdown]
# #Jobsheet2

# %% [markdown]
# Praktikum 1

# %%
# !pip install -q pandas matplotlib numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
num_cols = ['Age','Fare']
for col in num_cols:
    plt.figure()
    plt.hist(df[col], bins=30)
    plt.title(f'Distribusi {col}')
    plt.xlabel(col); plt.ylabel('Frekuensi')
    plt.show()


#Box Plot
plt.figure()
plt.boxplot(df['Fare'].dropna(), vert=True)
plt.title('Boxplot Fare')
plt.ylabel('Fare')
plt.show()

# %%
cat_cols = ['Survived','Pclass','Sex','Embarked']

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    df[col].value_counts(dropna=False).plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'Distribusi {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Jumlah')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns # Import seaborn for enhanced visualization

num_only = df.select_dtypes(include=[np.number])
corr = num_only.corr(numeric_only=True)

plt.figure(figsize=(8, 6)) # Increased figure size for better readability
sns.heatmap(corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, fmt=".2f") # Use seaborn.heatmap with annotation
plt.title('Heatmap Korelasi (numerik)')
plt.tight_layout()
plt.show()
corr['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
plt.figure()
surv_map = {0:'No', 1:'Yes'}
plt.scatter(df['Age'], df['Fare'], alpha=0.7)
plt.xlabel('Age'); plt.ylabel('Fare')
plt.title('Scatter Age vs Fare')
plt.show()

# %% [markdown]
# Praktikum 2

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Titanic-Dataset.csv')

# Tampilkan 5 data teratas
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Age - mean
df['Age'].fillna(value=df['Age'].mean(), inplace=True)

# Cabin - "DECK"
df['Cabin'].fillna(value="DECK", inplace=True)

# Embarked - modus
df['Embarked'].fillna(value=df['Embarked'].mode, inplace=True)
df.describe()
# Out:
# /tmp/ipython-input-1262292298.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(value=df['Age'].mean(), inplace=True)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# ...

# %%
df.info()
df.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ...

# %% [markdown]
# Praktikum 3

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
dpath = 'Titanic-Dataset-fixed.csv'
df = pd.read_csv(dpath)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  DECK        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  DECK        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  DECK        S

# %%
df = df[['Survived', 'Pclass', 'Age', 'Sex', 'Cabin']]
df.head()
# Out:
#    Survived  Pclass   Age     Sex Cabin
# 0         0       3  22.0    male  DECK
# 1         1       1  38.0  female   C85
# 2         1       3  26.0  female  DECK
# 3         1       1  35.0  female  C123
# 4         0       3  35.0    male  DECK

# %%
le = LabelEncoder() # membuat objek dari LabelEncoder
df['Sex'] = le.fit_transform(df['Sex']) # proses encoding
df['Cabin'] = le.fit_transform(df['Cabin']) # proses encoding
df.head()
# Out:
#    Survived  Pclass       Age  Sex  Cabin
# 0         0       3 -0.592481    1    115
# 1         1       1  0.638789    0     81
# 2         1       3 -0.284663    0    115
# 3         1       1  0.407926    0     55
# 4         0       3  0.407926    1    115

# %%
std = StandardScaler()
df['Age'] = std.fit_transform(df[['Age']])
df.head()
# Out:
#    Survived  Pclass       Age  Sex  Cabin
# 0         0       3 -0.592481    1    115
# 1         1       1  0.638789    0     81
# 2         1       3 -0.284663    0    115
# 3         1       1  0.407926    0     55
# 4         0       3  0.407926    1    115

# %% [markdown]
# Praktikum 4

# %%
# !pip install -q opencv-python matplotlib

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Membaca gambar (BGR default di OpenCV)
img = cv2.imread("Lenna.png")

# Konversi BGR → RGB (agar warnanya tampil benar di matplotlib)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Tampilkan
plt.imshow(img_rgb)
plt.title("Gambar Asli")
plt.axis("off")
plt.show()

# %%
# Resize gambar
img_resized = cv2.resize(img_rgb, (128, 128))

plt.imshow(img_resized)
plt.title("Gambar setelah Resize (128x128)")
plt.axis("off")
plt.show()

# %%
# Konversi ke grayscale
img_gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray, cmap="gray")
plt.title("Gambar Grayscale")
plt.axis("off")
plt.show()

# %% [markdown]
# #Tugas Praktikum 2

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Upload file wbc.csv via panel kiri “Files” di Colab
df = pd.read_csv('wbc.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print("Semua kolom:", df.columns.tolist())

# Buang kolom yang tidak relevan (contoh: id, unnamed)
drop_cols = [col for col in df.columns if 'id' in col.lower() or 'unnamed' in col.lower()]
df_used = df.drop(columns=drop_cols)

print("Kolom yang digunakan:", df_used.columns.tolist())
print("Kolom yang dibuang:", drop_cols)
# Out:
# Semua kolom: ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32']
# ...

# %%
le = LabelEncoder()
df_used['diagnosis'] = le.fit_transform(df_used['diagnosis'])
# Pastikan mappingnya:
mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Mapping diagnosis:", mapping)
df_used.head()
# Out:
# Mapping diagnosis: {'B': np.int64(0), 'M': np.int64(1)}
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
num_cols = df_used.select_dtypes(include=[np.number]).columns
scaler = StandardScaler()
df_used[num_cols] = scaler.fit_transform(df_used[num_cols])

# Tampilkan beberapa baris hasil:
df_used.head()
df_used.describe()
# Out:
#           diagnosis   radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean   4.995028e-17 -1.373633e-16  6.868164e-17   -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -7.706085e-01 -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -7.706085e-01 -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -7.706085e-01 -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    1.297676e+00  4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    1.297676e+00  3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean     -8.366672e-16      1.873136e-16    4.995028e-17        -4.995028e-17
# ...

# %% [markdown]
# # Pertemuan 3

# %% [markdown]
# Praktikum 1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import chi2, SelectKBest, RFE
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load Data
df = pd.read_csv("Titanic-Dataset.csv")

# Pisahkan Survived
y = df["Survived"].astype(int)
X = df.drop(columns=["Survived"])

# Buat list variabel numerik dan kategorikal
# Akan digunakan untuk proses seleksi fitur
# Name tidak akan digunakan karena tidak relevan
num_cols = ["Age", "SibSp", "Parch", "Fare"]
cat_cols = ["Pclass", "Sex", "Embarked"]

# %%
# Ekstaksi Fitur dengan Pipeline

# Data Numerik
num_tf = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# Data Kategorikal
cat_tf = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# %%
# Buat Fitur FamilySize
X["FamilySize"] = X["SibSp"].fillna(0) + X["Parch"].fillna(0) + 1

# Tambahkan FamilySize pada kelompok numerikal
preprocess = ColumnTransformer([
    ("num", num_tf, num_cols + ["FamilySize"]),
    ("cat", cat_tf, cat_cols),
])

# %%
from sklearn.feature_selection import f_classif
selector_filter = SelectKBest(score_func=f_classif, k=5)

# %%
# Seleksi fitur dengan SelectKBest
# Fungsi tersebut akan menggunakan analisis variance
# Baca: https://scikit-learn.org/stable/modules/feature_selection.html#univariate-feature-selection

from sklearn.feature_selection import f_classif
selector_filter = SelectKBest(score_func=f_classif, k=5)

# Buat pipeline final (INGAT INI HANYA PIPELINE, BELUM MEMPROSES DATA)
pipe_filter = Pipeline([
    ("prep", preprocess), # menjalankan pipeline preprocessing
    ("sel", selector_filter), # menjalankan pipeline seleksi fitur
    ("clf", LogisticRegression(max_iter=1000)) # uji dengan model sederhana -> Logistic Regression
])

# %%
# Lakukan pelatihan dan uji model
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

pipe_filter.fit(X_train, y_train)
pred = pipe_filter.predict(X_test)
print("=== Filter (ANOVA) + LR ===")
print("Accuracy:", accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# === Filter (ANOVA) + LR ===
# Accuracy: 0.776536312849162
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       110
#            1       0.73      0.67      0.70        69
#
#     accuracy                           0.78       179
#    macro avg       0.77      0.76      0.76       179
# weighted avg       0.77      0.78      0.77       179

# %%
# 1) Nama fitur setelah preprocess
feat_names = pipe_filter.named_steps["prep"].get_feature_names_out()
print("Nama fitur:", feat_names)
print("\n")

# 2) Mask & skor fitur terpilih (SelectKBest)
sel = pipe_filter.named_steps["sel"]
mask = sel.get_support()
selected_names = feat_names[mask]
selected_scores = sel.scores_[mask]
top = sorted(zip(selected_names, selected_scores), key=lambda t: t[1], reverse=True)[:10]
print("Top fitur:", top)
# Out:
# Nama fitur: ['num__Age' 'num__SibSp' 'num__Parch' 'num__Fare' 'num__FamilySize'
#  'cat__Pclass_1' 'cat__Pclass_2' 'cat__Pclass_3' 'cat__Sex_female'
#  'cat__Sex_male' 'cat__Embarked_C' 'cat__Embarked_Q' 'cat__Embarked_S']
#
#
# Top fitur: [('cat__Sex_female', np.float64(306.5932488951883)), ('cat__Sex_male', np.float64(306.59324889518797)), ('cat__Pclass_3', np.float64(80.33862734392042)), ('cat__Pclass_1', np.float64(73.99727564291717)), ('num__Fare', np.float64(58.31490728198491))]

# %% [markdown]
# Praktikum 2

# %%
corpus = [
    'the house had a tiny little mouse',
    'the cat saw the mouse',
    'the mouse ran away from the house',
    'the cat finally ate the mouse',
    'the end of the mouse story'
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Inisiasi obyek TFidfVectorizer
vect = TfidfVectorizer(stop_words='english')

# Pembobotan TF-IDF
resp = vect.fit_transform(corpus)

# Cetak hasil
print(resp)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 18 stored elements and shape (5, 12)>
#   Coords	Values
#   (0, 5)	0.47557510189256375
#   (0, 11)	0.5894630806320427
#   (0, 6)	0.5894630806320427
#   (0, 7)	0.2808823162882302
#   (1, 7)	0.3477147117091919
#   (1, 2)	0.5887321837696324
#   (1, 9)	0.7297183669435993
#   (2, 5)	0.47557510189256375
#   (2, 7)	0.2808823162882302
#   (2, 8)	0.5894630806320427
#   (2, 1)	0.5894630806320427
#   (3, 7)	0.2808823162882302
#   (3, 2)	0.47557510189256375
#   (3, 4)	0.5894630806320427
#   (3, 0)	0.5894630806320427
#   (4, 7)	0.3193023297639811
#   (4, 3)	0.6700917930430479
#   (4, 10)	0.6700917930430479

# %%
print(vect.get_feature_names_out())
# Out:
# ['ate' 'away' 'cat' 'end' 'finally' 'house' 'little' 'mouse' 'ran' 'saw'
#  'story' 'tiny']

# %% [markdown]
# Praktikum 3

# %%
# !pip install Pillow

# %%
from PIL import Image

img = Image.open('Lenna.png')
img.show() # tampilkan gambar
display(img) # metode alternatif tampilkan gambar
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# Ekstrak setiap channel red, green, blue
r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# 256
# ...

# %% [markdown]
# # tugas praktikum 3

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

df = pd.read_csv("wbc.csv")
#1
df = df.drop(columns=["id", "Unnamed: 32"], errors="ignore")
#2
label_enc = LabelEncoder()
df["diagnosis"] = label_enc.fit_transform(df["diagnosis"])
#3
X = df.drop(columns=["diagnosis"])
y = df["diagnosis"]
# 4
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("select", SelectKBest(score_func=f_classif)),
    ("clf", LogisticRegression(max_iter=500))
])
# 5
feature_range = range(5, X.shape[1] + 1)
scores = []

for k in feature_range:
    pipeline.set_params(select__k=k)
    cv_scores = cross_val_score(pipeline, X, y, cv=5, scoring="accuracy")
    scores.append(cv_scores.mean())

best_k = feature_range[int(np.argmax(scores))]
best_score = max(scores)

print("Jumlah fitur terbaik:", best_k)
print("Akurasi terbaik (CV 5-fold):", best_score)
# 6
pipeline.set_params(select__k=best_k)
pipeline.fit(X, y)
# 7
selector = pipeline.named_steps["select"]
mask = selector.get_support()
best_features = X.columns[mask]
print("\nFitur-fitur terbaik:")
print(best_features.tolist())
# Out:
# Jumlah fitur terbaik: 28
# Akurasi terbaik (CV 5-fold): 0.9806862288464524
#
# Fitur-fitur terbaik:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']
